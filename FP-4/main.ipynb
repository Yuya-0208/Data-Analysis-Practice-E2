# %% [markdown]
# # Final Project FP-3:  Descriptive Statistics
#
# <br>
# <br>

# %% [markdown]
# # Analysis of factors contributing to the expense on delicatessen in the supermarket
#
#
# ### Overview:
#
# * **Name**: Takahara Yuya
# * **Student number**: 0400377676
#
# <br>

# %% [markdown]
# ### Purpose:
#
# * The purpose of this Final Project is to identify the factors that are related to the customer's expense of delicatessen.
# * The key dependent variable (DV) is Delicassen, an integer between 3 and 47943.
# * Key independent variables (IVs) include:
#  * Fresh ("Fresh" column in the CSV file)
#  * Milk ("Milk" column in the CSV file)
#  * Grocery ("Grocery" column in the CSV file)
#  * Frozen ("Frozen" column in the CSV file)
#
# * This dataset contains 440 cases, a DV and four IV.
#
#
# <br>

# %% [markdown]
# ### Dataset source:
#
# The data come from the [Wholesale customers](https://archive.ics.uci.edu/dataset/292/wholesale+customers) dataset from the [UCI Machine Learning repository](https://archive.ics.uci.edu/ml/index.php)
#
# <br>

# %% [markdown]
# ### References:
#
# B. Lakshmi, K. Madhuri, M. Shashi (2017). An Efficient Algorithm for Density Based Subspace Clustering with Dynamic Parameter Setting

# %% [markdown]
# ___
#
# ## Descriptive Statistics

# %%
import pandas as pd
import parse_data
import descriptive 
from IPython.display import display

file_path = 'Wholesale customers data.csv' 

df = parse_data.load_and_preprocess_data(file_path)

# %%
descriptive.display_central_tendency_table(df, num=1)

descriptive.display_dispersion_table(df, num=2)
# Out:
# <br><br><p><span style="font-size: 1.2em;"><b>Table 1</b>: Central tendency summary statistics.</span></p>
#                  Fre         Milk          Gro          Fro         Deli
# mean    12000.297727  5796.265909  7951.277273  3071.931818  1524.870455
# median   8504.000000  3627.000000  4755.500000  1526.000000   965.500000
# mode        3.000000   577.000000   683.000000   133.000000     3.000000
# <br><br><p><span style="font-size: 1.2em;"><b>Table 2</b>: Dispersion summary statistics.</span></p>
#                    Fre          Milk           Gro          Fro          Deli
# st.dev.   12632.948725   7371.985612   9492.357638   4849.15352   2816.899449
# min           3.000000     55.000000      3.000000     25.00000      3.000000
# max      112151.000000  73498.000000  92780.000000  60869.00000  47943.000000
# range    112148.000000  73443.000000  92777.000000  60844.00000  47940.000000
# 25th       3127.750000   1533.000000   2153.000000    742.25000    408.250000
# ...

# %%
descriptive.plot_descriptive(df)
# Out:
# <p><span style="font-size: 1.2em;"><b>Figure 1</b>: Correlations amongst main variables.</span></p><br><br>
